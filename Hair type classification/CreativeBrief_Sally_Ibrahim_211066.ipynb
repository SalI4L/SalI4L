# %% [markdown]
# # Block C: Creative Brief Template
#
# Please, use this template to write down your solutions to the [DataLab Tasks](). If you have any questions, please, contact your mentor or the content responsible.
#
# ## Important Notes:
# - [ ] Please, rename the file to ```CreativeBrief_<your_name>_<studentnumber>.ipynb``` before submitting it.
# - [ ] Upload this template to the 'Deliverables' folder in you BUas GitHub repository.
# - [ ] You are allowed to add as many (Markdown/Python) cells as you need.
# - [ ] If more iteration steps were performed for the tasks in Section 3, please add more iteration sections.
# - [ ] If less iteration steps were needed for the tasks in Section 3, please remove the empty iteration sections.
# - [ ] If the task requires you to only write code or text, please, delete the unnecessary cell.
# - [ ] Your work should be reproducible, meaning that we should be able to run your code in the template and get the same results as you did. Tip: use relative paths to load your data!
# - [ ] Ensure that before you hand in the template, you press ```Restart & Run all```; we should be able to see the results of your code in the notebook (i.e., output cells).
# - [ ] Ensure that your code in the template is ```error-free```. In other words, we should not see any error messages when we run your code.

# %% [markdown]
# # Section 1 - Business Understanding (Week 1, Market Research for Product Development, Stakeholders & DAPS)

# %% [markdown]
# ## Task 1.1: Market Research

# %% [markdown]
#  __1. What image classifier product or product feature could make organizational life easier?__
#
# a classification model that classifies hair textures into 4 catagories (straight, wavy, curly and kinky), as it will help the consumers identify their hair time and get product recommendations, treatments and care routine that suits their hair texture the best.
#
# __2. How can I improve work within an organization?__
#
# the classification model will help people who don't know how to take care of their hair identify their hair texture and get product recommendations, treatments and care routine that suits their hair texture the best. the target audience will most likely be mixed race people, or mothers of mix raced kids. for example, a person who's parents have straight hair, but they're born with curly hair (considering that it is a dominant gene, and there might have been some generation skipping), the parents will have a hard time caring for the person's hair, thus, they will never learn how to take care of their hair properly and potentially use products and treatments that are damaging to their hair unless they do proper in-depth research and find people that have the same issue as them.
#
# __3. What problem can I alleviate for an organization?__
# Education and Consultation:
# Serve as an educational tool for consumers, helping them better understand their hair textures and providing guidance on suitable products and care routines.
#
# Diversity and Inclusion in Advertising:
# Contribute to more inclusive and diverse advertising campaigns by representing a broader spectrum of hair textures in marketing materials.
#
# Enhanced Product Development:
# Aid in the development of new hair care products by understanding the diverse range of hair textures, leading to more inclusive and effective formulations.
#
# Personalized Product Recommendations:
# Provide personalized product recommendations based on individuals' hair textures, enhancing the user experience in e-commerce platforms.
#
# Customized Hair Care Products:
# Assist in the formulation of customized hair care products tailored to specific hair textures, leading to more effective and targeted solutions for customers.

# %% [markdown]
# ## Task 1.2: Stakeholder Analysis

# %% [markdown]
# __1. Characteristics__
# - [Create a list detailing each stakeholder's characteristics here]
#
#
# End Users (Individuals with different hair textures):
#
# Power & Influence: Low to moderate in terms of model development but high in terms of model acceptance and impact.
# Interest: High, as they directly benefit from accurate hair texture classification.
# Expectations: Reliable and accurate classification results. User-friendly interface for interacting with the model.
# Needs: Clear explanations of the classification results, personalized recommendations for hair care based on the identified texture.
# Preferences: Privacy concerns need to be addressed, a visually appealing and intuitive user interface.
# Salon Professionals and Stylists:
#
# Salon Professionals and Stylists:
# Power & Influence: Moderate, especially if the model is used as a tool in their profession.
# Interest: Moderate to high, as it can aid in providing personalized hair care advice to clients.
# Expectations: Accurate classifications, easy integration into their workflow, and clear guidance for hair care.
# Needs: Training and resources to understand and use the model effectively, compatibility with salon software.
# Hair Care Product Manufacturers:
#
# Hair Care Product Manufacturers:
# Power & Influence: High, as the model's recommendations can influence product choices.
# Interest: High, as accurate classifications can lead to targeted product recommendations.
# Expectations: Integration possibilities with their product recommendations, insights into customer preferences.
# Needs: Access to the model's API for integration, data on user preferences, and compatibility with their existing platforms.
#
# Business Stakeholders (Company Executives, Investors):
# Power: High, as they control project resources.
# Influence: Decision-making on project funding and timelines.
# Interest: Return on investment, market impact, compliance with regulations.
# Expectations: Timely delivery, financial success, adherence to industry standards.
# Needs: Regular progress reports, risk assessments, market analysis.
# Preferences: Alignment with company goals, scalability, and potential for future applications.
#
# Model Developers:
#
# Power and Influence: High, as they build and maintain the model.
# Interest: Very high, as the success of the model reflects their skills and expertise.
# Expectations: Access to quality data, collaboration with domain experts, and acknowledgment for their work.
# Needs and Preferences: Adequate resources, support for research, and opportunities for professional growth.
# Domain Experts (Hair Texture Specialists):
#
# Domain Experts (Hair Texture Specialists):
# Power and Influence: High, as they provide valuable insights into the nuances of hair textures.
# Interest: Very high, as the accuracy of the model depends on their expertise.
# Expectations: Inclusion of their knowledge in model development, regular updates on model performance, and collaboration with developers.
# Needs and Preferences: Recognition of their expertise, involvement in decision-making, and transparent communication.
#
#
# __2. Prioritization__
# - [Prioritize stakeholders using the Power and Interest grid matrix]
#
# End Users (Individuals with different hair textures):
# Power: Low
# Interest: High
# Priority: Low Power, High Interest (Engage and keep informed)
#
# Salon Professionals and Stylists:
# Power: Medium
# Interest: High
# Priority: High Power, High Interest (Manage closely)
#
# Hair Care Product Manufacturers:
# Power: High
# Interest: Medium
# Priority: High Power, Low Interest (Keep satisfied)
#
# Business Stakeholders (Company Executives, Investors):
# Power: High
# Interest: High
# Priority: High Power, High Interest (Manage closely)
#
# Model Developers:
# Power: Medium
# Interest: Medium
# Priority: Medium Power, Medium Interest (Monitor and keep informed)
#
# Domain Experts (Hair Texture Specialists):
# Power: Medium
# Interest: Medium
# Priority: Medium Power, Medium Interest (Monitor and keep informed)
#
# __3. Main stakeholder__
# - [Identify your main stakeholder and provide a decision-making context for identifying your main stakeholder]
#
# End Users (Individuals with different hair textures):
# Accuracy and Reliability: End users expect the hair texture classification model to accurately and reliably classify their hair texture. They rely on the app to provide accurate assessments to guide their hair care routines and product choices.
# User-Friendly Interface: The app should have a user-friendly interface that is easy to navigate and understand. End users may come from diverse backgrounds and levels of technical proficiency, so the app should be intuitive and accessible to a wide range of users.
# Personalization: Users may have different hair care needs based on their hair texture. The app should offer personalized recommendations and tips tailored to their specific hair type.
# Privacy and Security: End users expect their data to be handled securely and with respect for their privacy. The app should have robust security measures in place to protect users' personal information and usage data.

# %% [markdown]
# Add additional text here!

# %% [markdown]
# ## Task 1.3: The DAPS Diagram

# %% [markdown]
# __1. The data-analytic problem__
# - [Fill in the lower part of the DAPS]
#
# what are the potenial predictors?
#
#   Curvature Analysis: Features related to the curvature of hair strands can help differentiate between straight, wavy and curly textures.
#
#   Texture Patterns: Features capturing texture patterns at various scales can be extracted using techniques like Gabor filters, Local Binary Patterns (LBP), or even deep learning-based texture descriptors such as those derived from Convolutional Neural Networks (CNNs).
#
#   Shape and Structure: Hair structure features like the length, thickness, and density of individual strands, as well as the overall shape and arrangement of the hair, can be informative.
#
#   Gradient Orientation: The orientation of hair strands and their variations across the image can provide cues for distinguishing between different textures.
#
#
# what is the type of the relationship?
#   -correlational
#
# what will the model predict?
#   The model will predict the texture of the hair given by processing the curl pattern of the strands
#
#
# __2. The decision framework__
# - [Fill in the middle part of the DAPS]
#
# for what decisions or actions will the model be used?
#    -what agent takes decisions?
#    -when are the decisions taken?
#    -what is the unit of analysis?
#    -intervention in x's?
#
# Decision Framework
# The model will be used to take decisions regarding the hair texture being analysed from the image given, it comes up with the prediction the gives hair care recommendations and products that the end-user can benefit from which is all based on the model's prediction
#
# __3. The business value__
# - [Fill in the upper part of the DAPS]
#
# what is the direct benefit of applying the decision framework?
# what will the project contribute to the organization's goals?
#
#
# DAPS Diagram github link: https://github.com/BredaUniversityADSAI/2023-24c-fai1-adsai-SallyIbrahim211066/blob/99e9e85e3698c7173daff9a966dafcd599c1bcc0/Deliverables/Week%202/DAPS%20diagram.drawio

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Task 1.4: The First Idea

# %% [markdown]
# The concept of the application is to classify different hair textures of users and recommend products and hair-care routines based on the hair texture given, which would make the classifier a feature in the application that helps user pick products which they can buy off of the application using affiliate links.
#
# The basic use-case flow chart goes as follows:
#
#
# ![image.png](attachment:image.png)
#
#
# By implementing such classifier it would help people gain more knowledge on how to treat, style and take care of their hair.

# %% [markdown]
# # Section 2A - Responsible AI (Fairness & Bias, Week 1)

# %% [markdown]
# ## Task 2.1: Create a Dataset

# %% [markdown]
# - Create a dataset by scraping the web for images (see instructions here), or selecting a subset of images from the Imsitu dataset, which you can find here.
# - The images must be colored, i.e., three channel images (RGB).
# - Select at least two classes from your dataset that contain a minimum of 100 images per class. Regarding the Imsitu dataset, you can use a noun, an agent, or a combination.
# - Upload the data to your BUAs SharePoint.
# - Create a training set that contains images from the selected classes.
# - Create a validation set that contains images from the selected classes.
# - Create a test set that contains images from the selected classes.

# %% [markdown]
# The code below was used to scrape the images.

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import requests
import os
import time

def download_image(image_url, directory, index):
    """
    Downloads an image from a given URL into a specified directory.
    """
    try:
        response = requests.get(image_url)
        if response.status_code == 200:
            file_path = os.path.join(directory, f'image_{index}.jpg')
            with open(file_path, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded {file_path}")
    except Exception as e:
        print(f"Error downloading {image_url}: {e}")

def scrape_images(search_term, limit):
    """
    Scrapes images from DuckDuckGo based on a search term up to a specified limit.
    """
    # Initialize the Chrome driver
    service = Service(ChromeDriverManager().install())
    driver = webdriver.Chrome(service=service)

    # Go to DuckDuckGo's image search page
    driver.get(f"https://duckduckgo.com/?q={search_term}&iax=images&ia=images")
    time.sleep(3)  # Allow time for the page to load

    # Scroll the page to ensure that images are loaded
    last_height = driver.execute_script("return document.body.scrollHeight")
    while True:
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(3)  # Wait for new images to load
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    # Find image elements on the page
    images = driver.find_elements(By.CSS_SELECTOR, "img.tile--img__img.js-lazyload")
    images = images[:limit]  # Limit the number of images to download

    # Create a directory for the downloaded images
    directory = f"downloaded_images_{search_term.replace(' ', '_')}"
    if not os.path.exists(directory):
        os.makedirs(directory)

    # Download the images
    for index, image in enumerate(images):
        image_url = image.get_attribute('src')
        if image_url:
            download_image(image_url, directory, index)

    driver.quit()
    print(f"Finished downloading images to {directory}.")

# Example usage
search_term = "curly hair"  # Specify the search term here
limit = 5  # Specify the maximum number of images to download

scrape_images(search_term, limit)

# %% [markdown]
# Split the data

# %%
import os
import shutil
import random

# Define paths to your dataset
dataset_dir = ".//Raw Dataset"
train_dir = ".//Dataset-F/train"
validation_dir = ".//Dataset-F/val"
test_dir = ".//Dataset-F/test"



# Define classes
classes = ['straight', 'wavy', 'curly']

# Define split percentages
train_percent = 0.7
validation_percent = 0.2
test_percent = 0.1

# Create directories if they don't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

if not os.path.exists(validation_dir):
    os.makedirs(validation_dir)

if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Iterate through each class
for class_name in classes:
    class_dir = os.path.join(dataset_dir, class_name)
    images = os.listdir(class_dir)
    random.shuffle(images)  # shuffle images randomly

    # Calculate split indices
    num_images = len(images)
    train_split = int(num_images * train_percent)
    validation_split = int(num_images * (train_percent + validation_percent))

    # Assign images to train, validation, and test sets
    train_images = images[:train_split]
    validation_images = images[train_split:validation_split]
    test_images = images[validation_split:]

    # Move images to appropriate directories
    for image in train_images:
        src = os.path.join(class_dir, image)
        dest = os.path.join(train_dir, class_name)
        if not os.path.exists(dest):
            os.makedirs(dest)
        shutil.copy(src, dest)

    for image in validation_images:
        src = os.path.join(class_dir, image)
        dest = os.path.join(validation_dir, class_name)
        if not os.path.exists(dest):
            os.makedirs(dest)
        shutil.copy(src, dest)

    for image in test_images:
        src = os.path.join(class_dir, image)
        dest = os.path.join(test_dir, class_name)
        if not os.path.exists(dest):
            os.makedirs(dest)
        shutil.copy(src, dest)

print("Dataset split successfully into train, validation, and test sets.")

# %% [markdown]
# ## Task 2.2: Identify, and Describe Bias

# %% [markdown]
# Define the concept of bias in relation to your own custom dataset or the full Imsitu dataset, and a computer vision task.
#
# **Gender bias in hair.**
#
#
# __List, and describe the type of bias that you identified in the dataset.__
#
# there was a clear gender bias in the dataset as over 97% of the images across all classes were of women with medium to long hair (thats 25 out of 839). images of men and people with short hair, however, were few and far in between, as it seems that when images of hair on google are mostly of women unless it is specified in the search prompt that the hair images are specifically of men or non-binary people.
#
#
#
# __Discuss the possible ramifications (e.g., harm) in terms of fairness of the identified bias instance:
# Why, and when, is this particular instance of bias undesirable? In other words, who might be disproportionally affected by this particular instance of bias, and when does this negative effect come into play?__
#
# The identified gender bias in the dataset, where over 97% of the images are of women with medium to long hair, can have several ramifications in terms of fairness. This bias can result in a skewed and unrepresentative model, leading to issues in various domains:
#
#
# Reinforcement of Stereotypes: The overrepresentation of women, especially with long hair, reinforces traditional gender stereotypes. It perpetuates the notion that certain physical attributes are inherently linked to a specific gender, potentially reinforcing societal norms that associate femininity with long hair.
#
# Underrepresentation and Marginalization: Men and individuals with shorter hair are underrepresented in the dataset. This can lead to the marginalization of these groups, as the lack of diverse representation may contribute to their invisibility in image-related applications and technologies.
#
# Algorithmic Discrimination: Applications that use the biased dataset may inadvertently contribute to algorithmic discrimination. For example, image-based algorithms in areas like facial recognition, beauty standards, or hiring processes might favor characteristics associated with the overrepresented group (women with long hair), potentially leading to unfair outcomes for others.
#
# Perpetuation of Gender Inequality: The bias in the dataset reflects and perpetuates existing gender inequalities. By primarily showcasing images of women, it may contribute to a skewed representation of gender roles and occupations, influencing perceptions and reinforcing gender imbalances in various fields.
#
# Social and Economic Consequences: If biased datasets influence decision-making processes in areas such as recruitment, marketing, or personal identification, there can be social and economic consequences. Unintentional discrimination against certain gender groups may lead to disparities in opportunities, services, or access to resources.
#
# Negative Impact on Men's Grooming and Beauty Industries: The underrepresentation of men in images related to hair might contribute to a lack of visibility for men's grooming and beauty industries. This could reinforce the stereotype that hair care and grooming are primarily associated with women, potentially limiting the growth and acceptance of these industries for men.

# %% [markdown]
# ## Task 2.3: Propose Individual Fairness Method

# %% [markdown]
# 1. Identify a sensitive/protected attribute in either your own custom dataset or in the full Imsitu dataset.
#
#
# in this dataset of hair textures, a sensitive/protected attribute could be the gender of the individuals depicted in the images. The imbalance in gender representation, with over 97% of the images being of women, indicates a potential bias. This bias might affect the model's performance and generalization, especially when it comes to predicting or analyzing hair textures for men or people with short hair.
#
# It's essential to be mindful of such biases to ensure fair and unbiased outcomes when working with machine learning models. Consider addressing this issue by either augmenting the dataset to include more diverse representations or implementing strategies to mitigate the impact of gender bias in the training process. Additionally, documenting and being transparent about the dataset's limitations is crucial when using or sharing the results of the model.
#
#
# 2. Choose an individual fairness method: ‘Fairness Through Unawareness' or ‘Fairness Through Awareness', to address bias related to the sensitive/protected attribute in the chosen dataset.
#
# In this case, "Fairness Through Awareness" would be a more suitable approach to address bias related to the sensitive/protected attribute (gender) in the hair texture dataset.
#
# "Fairness Through Unawareness" involves training the model without explicitly considering the sensitive attribute to achieve fairness. However, given the gender bias in the dataset and the potential impact on the model's performance, it's essential to be aware of and explicitly address these biases.
#
# "Fairness Through Awareness" involves incorporating the sensitive attribute into the model training process and actively working to mitigate bias. In this context, you could implement techniques such as re-sampling, re-weighting, or using fairness-aware algorithms to ensure that the model considers and appropriately handles gender-related biases in the dataset.
#
# By choosing "Fairness Through Awareness," you acknowledge the existence of the sensitive attribute and take deliberate steps to promote fairness in the model's predictions, especially concerning different genders and hair textures.
#
# 3. Elaborate on the individual fairness method that you selected, and explain why you think it is an effective method to address bias related to the sensitive/protected attribute in the chosen dataset.
#
# "Fairness Through Awareness" involves incorporating the sensitive or protected attribute information into the model training process to actively address and mitigate biases. In the context of the hair texture dataset with gender bias, here are some strategies you could consider:
#
# Re-sampling or Over-sampling:
#
# Increase the representation of under-represented classes (e.g., men or individuals with short hair) to balance the dataset.
# This ensures that the model is exposed to a more diverse set of examples, reducing the likelihood of learning biased patterns associated with the majority class.
# Re-weighting:
#
# Assign different weights to instances based on their class and the sensitive attribute (gender).
# By giving more importance to under-represented classes, you can influence the model to pay more attention to the minority groups and reduce bias.
# Fairness-aware Algorithms:
#
# Use algorithms specifically designed to address fairness concerns. These algorithms often include regularization terms or constraints that penalize the model for making decisions that disproportionately favor one group over another.
# Fairness-aware algorithms can be integrated into various machine learning models to ensure that the training process considers the sensitive attribute.
#
# Fairness Through Awareness is an effective method to address bias related to the sensitive attribute in the hair texture dataset because it explicitly acknowledges the presence of gender bias and takes proactive steps to mitigate its impact. By incorporating gender into the model training process and actively promoting fairness through algorithmic techniques, Fairness Through Awareness helps ensure that the model's predictions are equitable across different gender categories. This approach aligns with principles of fairness and social justice, promoting inclusive and unbiased decision-making in machine learning applications.

# %% [markdown]
# ## Task 2.4: Create Infographic; Group Fairness Metrics

# %% [markdown]
# https://github.com/BredaUniversityADSAI/2023-24c-fai1-adsai-SallyIbrahim211066/blob/888adb5ad142b8676f8b5ebaa32859e78d16ef2b/Group-Fairness%20InfoGraphic.pdf

# %% [markdown]
# __1. Strengths__
# - *Filled in by yourself and your peer, separately*
# - Borges Varela, Deuza (235065)
# - It looks good, and the main idea on the parameters is there.
# Improvement points: The subjects are not very well developed and you are missing the real world examples. Apart from that it looks clean and informative.
# - My evaluation:
# - I think that my infographic is straight to the point. it explains what is group fairness, as well as explaining 3 metrics (Independence, seperation, sufficiency), it has examples of real-world impacts and implementations. i think that my visuals are decent and the colours chosen give a nice contrast with the dark blue and the pale yellow. the infographic is divided into sections for easy reading.
#
# __2. Areas for Improvement__
# - Borges Varela, Deuza (235065) Points of improvement:
# Elaborate on the subjects and add examples.
# - My evaluation:
# - I think there can be some rooms for improvement in my infographic, for example, i could go more in depth in the definitions and examples.
# - [Describe areas for improvement of your infographic here]
#
# __3. Next Steps for Improvement__
# -  *Filled in by yourself with the help of the peer reviewer*
# - I am looking to add more details into my infographic while keeping the visuals and spacing in mind to avoid over-crowding.
# - [List actionable steps for improvement of your infographic here]
#
# __4. Reflection__
# - *Filled in by yourself*
# - I found the process of making the info-graphic to be rather confusing at first, because i assumed that i was supposed to make it relevant to my project, which was not the case. once that issue was cleared i found it easier to create the infographic, the design was easy to make, and the research was reasonable. I did grasp the concepts i was writing about eventually, So explaining the metrics was easy. i showed my peers my infographic to which they gave me useful feedback, for things to add and visuals.
#
# __5. Infographic__
# - Link: https://github.com/BredaUniversityADSAI/2023-24c-fai1-adsai-SallyIbrahim211066/blob/888adb5ad142b8676f8b5ebaa32859e78d16ef2b/Group-Fairness%20InfoGraphic.pdf

# %% [markdown]
# ## Task 2.5: Write Python Function; Group Fairness Taxonomy

# %% [markdown]
# Add your text here! (e.g., links to Jupyter Notebook or Python script(s), and model weight file or confusion matrices of the two test sets).

# %% [markdown]
# # Section 2B - Responsible AI (Transparency & Interpretability, Week 6)

# %% [markdown]
# ## Task 2.6: Apply One/Multiple Explainable AI Method(s) to the Image Classifier

# %% [markdown]
# Add your text here!

# %%
# Add your code here!

# %% [markdown]
# # Section 3 - Neural Networks and Deep Learning (Weeks 2 to 5)

# %%
import numpy as np
import skimage as ski
from keras.utils import to_categorical
import sklearn as ski
from tensorflow import keras
from sklearn import preprocessing
from skimage import io as ski_io
from keras.utils import to_categorical
import sklearn as ski
from tensorflow import keras
from sklearn import preprocessing
import os
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam
# Out:
# WARNING:tensorflow:From c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## Task 3.1: Baselines

# %% [markdown]
# ### 1. Random Guess Accuracy

# %% [markdown]
# To do the random guess accuracy, the number of classes (n) are devided by 1. for example, in my classification model, I have 3 classes which means that n = 3.
#
# Thus, the random Guess accuracy = $\frac{1}{n} = \frac{1}{3} = 33.3\%$

# %% [markdown]
# ### 2. Human-Level Performance Accuracy

# %% [markdown]
# Human-level performance accuracy refers to the level of accuracy achieved by humans in completing a task or solving a problem. It's a benchmark that represents the standard at which humans typically operate. Achieving human-level performance accuracy means reaching a level of proficiency comparable to that of an average person in a particular domain.
#
# This concept is often used in fields such as artificial intelligence and machine learning to assess the effectiveness of algorithms and systems. When a machine or AI system achieves human-level performance accuracy, it implies that it can perform tasks or solve problems with a similar degree of accuracy and reliability as a human would.
#
# To calculate Human-level performance accuracy, a form was created with 51 questions to ask people to classifiy the images given to them into 3 catagories (straight, wavy, curly/Kinky).
#
#
# Form link: https://forms.office.com/e/t9V21fNYyc
#
# These are the results:
#
# - respondant 1: 96%
# - respondant 2: 88%
# - respondant 3: 86%
# - respondant 4: 90%
# - respondant 5: 92%
# - respondant 6: 84%
# - respondant 7: 84%
# - respondant 8: 80%
# - respondant 9: 92%
# - respondant 10: 80%
# - respondant 11: 80%
# - respondant 12: 86%
# - respondant 13: 86%
# - respondant 14: 90%
# - respondant 15: 84%
#
# The average human-level accuracy is = 96% + 88% + 86% + 90% + 92% + 84% + 84% + 80% + 92% + 80% + 80% + 86% + 86% + 90% + 84% = 1314%
#
# Now, divide by the total number of respondants, which is 15:
#
# 1314% / 15 = 87.6%
#
# The average human-level accuracy is 87.6%

# %% [markdown]
# ### 3. Basic Multilayer Perceptron Accuracy

# %% [markdown]
# Define a Basic Multilayer Perceptron Baseline, which serves as a reference of - what is possible to achieve with a basic neural network.
# - Build a Multilayer Perceptron (MLP) model with Keras.
# - Train and test the model.
# - Plot learning curves for the baseline MLP model.
# - Use early stopping in the baseline MLP model.
# - Train and evaluate the baseline MLP model with different learning rates.
# - Calculate the baseline accuracy for the dataset based on the MLP model.

# %% [markdown]
# In the next two cells of code, the data is processed. starting by loading the images local folder into the notebook. then the dataset is split into 'training', validation' and testing sets with the ratios of 7:2:1 respectively. thus, making the data useable.

# %%
from skimage import io as ski_io
import os
import numpy as np
import skimage as ski

# Folder paths where the images of each class are stored
folder_paths = [
    r".//Raw Dataset/Straight",
    r".//Raw Dataset/Wavy",
    r".//Raw Dataset/Curly",
]

# Class labels for the images (same order as folder_paths)
class_names = [
    "Straight",
    "Wavy",
    "Curly"
]

# Target size to resize the images
target_size = (256, 256)

# Arrays to store the images (X) and class labels (y)
X = []
y = []

for i in range(len(folder_paths)):
    for filename in os.listdir(folder_paths[i]):
        file_extension = os.path.splitext(filename)[1]
        # Check if the file extension is an image extension
        if file_extension == ".jpg" or file_extension == ".jpeg" or file_extension == ".png":
            image_filename = os.path.join(folder_paths[i], filename)
            # Read the image file using scikit-image
            image = ski.io.imread(image_filename)
            # Resize the image to the target_size
            image_resized = ski.transform.resize(image, target_size)
            if image_resized.shape == (256, 256, 3):
                # Normalize the image
                image_normalized = image_resized / 255.0
                # Insert the image into array X
                X.append(image_normalized)
                # Insert the class label into array y
                y.append(class_names[i])
            else:
                print(filename)

# Convert of arrays into numpy arrays
X_MLP = np.array(X)
y_MLP = np.array(y)

# %%
# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_MLP, y_MLP, test_size = 1/10, random_state = 0)
print(X_train.shape, X_test.shape)

# Split the data into train, test and validations sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 2/9, random_state = 0)
print("Shape of X_train before resizing:", X_train.shape)
print("Shape of X_test before resizing:", X_test.shape)
print("Shape of X_val before resizing:", X_val.shape)

# Reshape the input data
X_train_reshaped = X_train.reshape(-1,256*256*3)
X_test_reshaped = X_test.reshape(-1, 256*256*3)
X_val_reshaped = X_val.reshape(-1, 256*256*3)

# Print the shapes of reshaped input data
print("Shape of X_train after resizing:", X_train_reshaped.shape)
print("Shape of X_test after resizing:", X_test_reshaped.shape)
print("Shape of X_val after resizing:", X_val_reshaped.shape)

# Initialize LabelEncoder
label_encoder = preprocessing.LabelEncoder()

# Fit and transform integer labels for training set
y_train_integer_encoded = label_encoder.fit_transform(y_train)
y_train_onehot_encoded = to_categorical(y_train_integer_encoded, num_classes=3)
print("Shape of y_train_onehot_encoded:", y_train_onehot_encoded.shape)

# Fit and transform integer labels for test set
y_test_integer_encoded = label_encoder.transform(y_test)
y_test_onehot_encoded = to_categorical(y_test_integer_encoded, num_classes=3)
print("Shape of y_test_onehot_encoded:", y_test_onehot_encoded.shape)

# Fit and transform integer labels for validation set
y_val_integer_encoded = label_encoder.transform(y_val)
y_val_onehot_encoded = to_categorical(y_val_integer_encoded, num_classes=3)
print("Shape of y_val_onehot_encoded:", y_val_onehot_encoded.shape)
# Out:
# (730, 256, 256, 3) (82, 256, 256, 3)
# Shape of X_train before resizing: (567, 256, 256, 3)
# Shape of X_test before resizing: (82, 256, 256, 3)
# Shape of X_val before resizing: (163, 256, 256, 3)
# Shape of X_train after resizing: (567, 196608)
# Shape of X_test after resizing: (82, 196608)
# Shape of X_val after resizing: (163, 196608)
# Shape of y_train_onehot_encoded: (567, 3)
# Shape of y_test_onehot_encoded: (82, 3)
# Shape of y_val_onehot_encoded: (163, 3)

# %% [markdown]
# In the next cells of code, the basic model is built, starting with defining the model architecture. creating a sequential model using keras, and the final output dense layer is employed using softmax activation.
#
# The model is then compiled using the "Catagorical cross-entropy" as a loss function and "adam" as an optimizer.
#
# Then, the model is trained by fitting it to the training data. to increase performace, the number of the validation data, batch size and epochs are specified. the learning rate "lr" and "early stopping" functions are used to mitigate overfitting
#
# once the model is trained, the model is evaluated by printing the accuracy and loss.

# %%
# Build the Baseline MLP model
model_MLP = Sequential([
    Dense(128, activation="relu", input_shape=(X_train_reshaped.shape[1], )),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(3, activation="softmax")
])

# Compile the model
model_MLP.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history_MLP = model_MLP.fit(X_train_reshaped, y_train_onehot_encoded, epochs=30, batch_size=32,
                    validation_data=(X_val_reshaped, y_val_onehot_encoded))

# Evaluate the model
loss, accuracy = model_MLP.evaluate(X_test_reshaped, y_test_onehot_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# WARNING:tensorflow:From c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/30
# WARNING:tensorflow:From c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# ...

# %%
# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot learning curves for accuracy and validation accuracy
axs[0].plot(history_MLP.history["accuracy"], label="Train Accuracy")
axs[0].plot(history_MLP.history["val_accuracy"], label="Validation Accuracy")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].set_title("Accuracy vs. Epochs")
axs[0].legend()

# Plot learning curves for loss and validation loss
axs[1].plot(history_MLP.history["loss"], label="Train Loss")
axs[1].plot(history_MLP.history["val_loss"], label="Validation Loss")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].set_title("Loss vs. Epochs")
axs[1].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# summary:
# Epochs and Training:
# - The model is trained for 30 epochs, similar to the previous example. Each epoch involves iterating through the training data to adjust the model's weights based on the optimization algorithm.
#
# Performance Metrics:
# - The training process displays metrics such as loss and accuracy for both training and validation datasets for each epoch. Loss indicates the difference between predicted and actual values, while accuracy measures the proportion of correctly classified samples.
#
# Validation Accuracy:
# - Like before, validation accuracy provides insight into the model's generalization performance. In this case, the validation accuracy fluctuates but generally hovers around 0.6, indicating moderate performance.
#
# Test Performance:
# - After training, the model is evaluated on a separate test dataset. The test loss is approximately 1.43, and the test accuracy is around 0.60. These metrics show how well the model generalizes to new, unseen data.

# %%
from keras.callbacks import EarlyStopping

# Build the Baseline MLP model
model_MLP = Sequential([
    Dense(128, activation="relu", input_shape=(X_train_reshaped.shape[1], )),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(3, activation="softmax")
])

# Define the early stopping callback
early_stopping = EarlyStopping(monitor='val_accuracy', patience=2, restore_best_weights=True)

# Compile the model
model_MLP.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model with early stopping
history_MLP = model_MLP.fit(X_train_reshaped, y_train_onehot_encoded, epochs=30, batch_size=32,
                    validation_data=(X_val_reshaped, y_val_onehot_encoded), callbacks=[early_stopping])

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 5))

# Plot learning curves for accuracy and validation accuracy
axs[0].plot(history_MLP.history["accuracy"], label="Train Accuracy")
axs[0].plot(history_MLP.history["val_accuracy"], label="Validation Accuracy")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].set_title("Accuracy vs. Epochs")
axs[0].legend()

# Plot learning curves for loss and validation loss
axs[1].plot(history_MLP.history["loss"], label="Train Loss")
axs[1].plot(history_MLP.history["val_loss"], label="Validation Loss")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].set_title("Loss vs. Epochs")
axs[1].legend()

plt.tight_layout()
plt.show()

# Evaluate the model on the test set
loss, accuracy = model_MLP.evaluate(X_test_reshaped, y_test_onehot_encoded)
print("Test Loss:", loss)
print("Test Accuracy:", accuracy)
# Out:
# Epoch 1/30
# 18/18 [==============================] - 6s 218ms/step - loss: 1.0803 - accuracy: 0.3933 - val_loss: 1.0114 - val_accuracy: 0.4601
# Epoch 2/30
# 18/18 [==============================] - 3s 181ms/step - loss: 1.0045 - accuracy: 0.4903 - val_loss: 0.9879 - val_accuracy: 0.4724
# Epoch 3/30
# 18/18 [==============================] - 3s 181ms/step - loss: 0.9954 - accuracy: 0.5044 - val_loss: 0.9304 - val_accuracy: 0.5644
# Epoch 4/30
# 18/18 [==============================] - 3s 171ms/step - loss: 0.9351 - accuracy: 0.5467 - val_loss: 0.9072 - val_accuracy: 0.5828
# Epoch 5/30
# 18/18 [==============================] - 3s 171ms/step - loss: 0.9157 - accuracy: 0.5503 - val_loss: 0.9279 - val_accuracy: 0.5706
# Epoch 6/30
# 18/18 [==============================] - 3s 173ms/step - loss: 0.9168 - accuracy: 0.5309 - val_loss: 0.9734 - val_accuracy: 0.5890
# Epoch 7/30
# ...

# %% [markdown]
# The training process was stopped early at the 8th epoch due to the implementaion of early stopping, which was caused by the validation loss stopped improving, which indicates that further training might lead to overfitting.
#
# Epochs and Training:
# - The model is trained for 30 epochs, but early stopping was used, meaning training stopped before reaching the maximum number of epochs based on certain criteria, likely validation loss not improving.
#
# Performance Metrics:
# - The training process displays both training and validation metrics for each epoch. The "loss" indicates how well the model is performing (lower is better), while "accuracy" represents the proportion of correctly classified samples.
#
# Validation Accuracy:
# - Throughout the training epochs, the validation accuracy gradually increases, starting from around 0.46 and reaching approximately 0.57 by the eighth epoch. This indicates that the model is learning and improving its performance on unseen validation data.
#
# Test Performance:
# - After training, the model is evaluated on a separate test dataset. The test loss is approximately 0.97, and the test accuracy is around 0.48. These metrics provide insights into how well the model generalizes to new, unseen samples.
#
# Early Stopping:
# - Early stopping was implemented, indicating that the training process was monitored for certain criteria, likely the validation loss not improving, and training was halted to prevent overfitting and unnecessary computation.

# %%
from tensorflow.keras.optimizers import Adam

# Define the range of learning rates to experiment with
learning_rates = [0.0001, 0.001, 0.01, 0.1]

# Create lists to store performance metrics
accuracy_scores = []
loss_scores = []

# Loop through the learning rates
for lr in learning_rates:
    # Create a new instance of the baseline MLP model
    model = Sequential([
    Dense(128, activation="relu", input_shape=(X_train_reshaped.shape[1], )),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(64, activation="relu"),
    Dense(3, activation="softmax")
])

    # Compile the model with the specified learning rate
    optimizer = Adam(lr=lr)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    # Train the model
    model.fit(X_train_reshaped, y_train_onehot_encoded, epochs=30, batch_size=32, verbose=0)

    # Evaluate the model on the test set
    loss, accuracy = model.evaluate(X_test_reshaped, y_test_onehot_encoded)

    # Record the accuracy for this learning rate
    accuracy_scores.append(accuracy)
    loss_scores.append(loss)

for lr, acc, ls in zip(learning_rates, accuracy_scores, loss_scores):
    print(f"Learning Rate: {lr}, Accuracy: {acc}, Loss: {ls}")
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 3/3 [==============================] - 0s 12ms/step - loss: 1.1032 - accuracy: 0.6220
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 3/3 [==============================] - 0s 13ms/step - loss: 1.2694 - accuracy: 0.6341
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# 3/3 [==============================] - 0s 12ms/step - loss: 1.3117 - accuracy: 0.6463
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# ...

# %% [markdown]
# For the learning rate of 0.0001 the accuracy came at 62% on the test set, as for the loss, it same it 1.1. despite the low learning rate, the model had decent results.
#
# For the learning rate of 0.001 the accuracy came at 63% on the test set, as for the loss, it same it 1.26. the difference from the previous learning rate is not major. though it seems that as the accuracy increases, the loss increases along with it.
#
# For the learning rate of 0.01 the accuracy came at 64% on the test set, as for the loss, it same it 1.31. this has been the best performace shown by far, by having a decent balance between speed and accuracy.
#
# Finally, for the learning rate of 0.1 the accuracy came at 60% on the test set, as for the loss, it same it 1.21. the lowest accuracy recorded by far, and the 3rd highest loss.
#
# Based on these results, it seems that a learning rate of 0.001 performs best for this model on this dataset.

# %% [markdown]
# ## Task 3.2 Preprocessing

# %% [markdown]
# ### Iteration 1

# %% [markdown]
# now that the baselines have been established, the ability to compare the performances of the ML models is provided. in this process in the project lifecycle, the data is cleaned and preprocessed to be used in the model effectively. that involves, dealing with missing values, rescaling, reshaping and resizing the data.
#
# it follows the same steps performed in the earlier cells, which are loading the dataset by defining it, labeling the classes, resizing the images to 256x256. two empty arrays are created "og_X" and "og_y" to carry images and their labels. then the folders are looped, to check it each image is in the right format "JPG, PNG, JPEG". the data is in split.

# %%
from skimage import io as ski_io
import os
import numpy as np
import skimage as ski

# Folder paths where the images of each class are stored
folder_paths = [
    r".//Raw Dataset/Straight",
    r".//Raw Dataset/Wavy",
    r".//Raw Dataset/Curly",
]

# Class labels for the images (same order as folder_paths)
class_names = [
    "Straight",
    "Wavy",
    "Curly"
]

# Target size to resize the images
target_size = (256, 256)

# Arrays to store the images (X) and class labels (y)
og_X = []
og_y = []

for i in range(len(folder_paths)):
    for filename in os.listdir(folder_paths[i]):
        file_extension = os.path.splitext(filename)[1]
        # Check if the file extension is an image extension
        if file_extension == ".jpg" or file_extension == ".jpeg" or file_extension == ".png":
            image_filename = os.path.join(folder_paths[i], filename)
            # Read the image file using scikit-image
            image = ski.io.imread(image_filename)
            # Resize the image to the target_size
            image_resized = ski.transform.resize(image, target_size)
            if image_resized.shape == (256, 256, 3):
                # Normalize the image
                image_normalized = image_resized / 255.0
                # Insert the image into array X
                og_X.append(image_normalized)
                # Insert the class label into array y
                og_y.append(class_names[i])
            else:
                print(filename)


# Convert of arrays into numpy arrays
og_X = np.array(og_X)
og_y = np.array(og_y)

# Initialize LabelEncoder with class names
label_encoder = preprocessing.LabelEncoder()
label_encoder.classes_ = np.array(class_names)

# Encode class labels
y_integer_encoded = label_encoder.transform(og_y)

# Convert integer-encoded labels into one-hot encoded vectors
y_onehot_encoded = keras.utils.to_categorical(y_integer_encoded, num_classes=len(class_names))
print("Shape of y_onehot_encoded:", y_onehot_encoded.shape)

# Split the data into train and test sets
from sklearn.model_selection import train_test_split
og_X_train, og_X_test, og_y_train, og_y_test = train_test_split(og_X, y_onehot_encoded, test_size = 1/10, random_state = 0)

# Split the data into train, test and validations sets
og_X_train, og_X_val, og_y_train, og_y_val = train_test_split(og_X_train, og_y_train, test_size = 2/9, random_state = 0)
print("Shape of X_train:", og_X_train.shape)
print("Shape of X_val:", og_X_val.shape)
print("Shape of X_test:", og_X_test.shape)
# Out:
# Shape of y_onehot_encoded: (812, 3)
# Shape of X_train: (567, 256, 256, 3)
# Shape of X_val: (163, 256, 256, 3)
# Shape of X_test: (82, 256, 256, 3)

# %% [markdown]
# the y_onehot_encoded labels contains 812 images and not the expected 900 images. there are 3 classes in the dataset.
#
# as such, the validation and training datasets are missing a few images, but it will likely not affect the dataset. the data is split into training, validation, testing with a 7:2:1 ratios.
#
# Below, the one-hot encoding is performed, and the labels assigned to what class can be seen.

# %%
# Display information before one-hot encoding
print("Class names before encoding:", class_names)
print("Unique integer encoded labels:", np.unique(y_integer_encoded))
print("Number of classes:", len(class_names), "\n")

# Iterate through unique integer encodings
for integer_encoding in np.unique(y_integer_encoded):
    # Find the index of this integer encoding in the y_integer_encoded array
    index = np.where(y_integer_encoded == integer_encoding)[0][0]
    # Get the corresponding class name
    class_name = og_y[index]
    # Print the class name, integer encoding, and its corresponding one-hot encoding
    print("Class Name:", class_name)
    print("Integer Encoding:", integer_encoding)
    print("One-Hot Encoding:", y_onehot_encoded[index])
    print()
# Out:
# Class names before encoding: ['Straight', 'Wavy', 'Curly']
# Unique integer encoded labels: [0 1 2]
# Number of classes: 3
#
# Class Name: Straight
# Integer Encoding: 0
# One-Hot Encoding: [1. 0. 0.]
#
# Class Name: Wavy
# Integer Encoding: 1
# One-Hot Encoding: [0. 1. 0.]
#
# Class Name: Curly
# Integer Encoding: 2
# One-Hot Encoding: [0. 0. 1.]

# %% [markdown]
# in the output of the cell above, it shows the information dataset before one-hot coding, containing the name and number of the classes as well as the unique inter encodings. the analysis is performed to make sure that the data is properly prepared and to verify the one-hot encoding is excecuted properly.
# Each class is encoded in binary format, that being "0" for absent class and "1" for present class.
#
# In the next cell, the preprocessed data is assigned to the variables in the first iteration in the CNN model.

# %%
V1_X_train = og_X_train
V1_X_test = og_X_test
V1_X_val = og_X_val

V1_y_train = og_y_train
V1_y_test = og_y_test
V1_y_val = og_y_val

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# In this iteration, data augmentation is used to expand the dataset in a less time consuming approach. In the ML project lifecycle, the model having low accuracy often results in insuffiecient data, which is why data augmentation is chosen to deal with the issue.
#
# data augmentation is a function/ technique that alters the shape of the images in different ways, resulting in increased yet somewhat similar images in the dataset.
#
# the methods used in this iteration using keras are:
# - image zooming
# - image rotation
# - horizontal image flipping

# %%
import os
import numpy as np
import skimage as ski
from skimage import transform
from sklearn import preprocessing
from keras.utils import to_categorical
from tensorflow import keras
from tensorflow.keras import layers


# Folder paths where the images of each class are stored
folder_paths = [
    r".//Raw Dataset/Straight",
    r".//Raw Dataset/Wavy",
    r".//Raw Dataset/Curly",
]

# Class labels for the images (same order as folder_paths)
class_names = [
    "Straight",
    "Wavy",
    "Curly"
]

# Target size to resize the images
target_size = (256, 256)

# Arrays to store the images (X) and class labels (y)
augumented_X = []
augumented_y = []

# Creates the preprocessing layer for data augmentation
data_augmentation = keras.Sequential(
    [
        layers.RandomRotation(0.1),
        layers.RandomZoom(0.2),
        layers.RandomFlip("horizontal"),
    ])

for i in range(len(folder_paths)):
    for filename in os.listdir(folder_paths[i]):
        file_extension = os.path.splitext(filename)[1]
        # Check if the file extension is an image extension
        if file_extension == ".jpg" or file_extension == ".jpeg" or file_extension == ".png":
            image_filename = os.path.join(folder_paths[i], filename)
            # Read the image file using scikit-image
            image = ski.io.imread(image_filename)
            # Resize the image to the target_size
            image_resized = ski.transform.resize(image, target_size)
            if image_resized.shape == (256, 256, 3):
                # Append original image to X and corresponding label to y
                augumented_X.append(image_resized)
                augumented_y.append(class_names[i])
                # Apply augmentation once
                augmented_images = data_augmentation(np.expand_dims(image_resized, axis=0))
                # Insert the augmented images into array X
                for augmented_image in augmented_images:
                    augumented_X.append(augmented_image)
                    # Insert the class label into array y
                    augumented_y.append(class_names[i])
            else:
                print(filename)

# Convert arrays into numpy arrays
augumented_X = np.array(augumented_X)
augumented_y = np.array(augumented_y)

# Initialize LabelEncoder with class names
label_encoder = preprocessing.LabelEncoder()
label_encoder.classes_ = np.array(class_names)

# Encode class labels
augumented_y_integer_encoded = label_encoder.transform(augumented_y)

# Convert integer-encoded labels into one-hot encoded vectors
augumented_y_onehot_encoded = keras.utils.to_categorical(augumented_y_integer_encoded, num_classes=len(class_names))
print("Shape of augumented y_onehot_encoded:", augumented_y_onehot_encoded.shape)

# Split the data into train and test sets
from sklearn.model_selection import train_test_split
augumented_X_train, augumented_X_test, augumented_y_train, augumented_y_test = train_test_split(augumented_X, augumented_y_onehot_encoded, test_size=1/10, random_state=0)

# Split the data into train, test, and validation sets
augumented_X_train, augumented_X_val, augumented_y_train, augumented_y_val = train_test_split(augumented_X_train, augumented_y_train, test_size=2/9, random_state=0)
print("Shape of augumented X_train:", augumented_X_train.shape)
print("Shape of augumented X_val:", augumented_X_val.shape)
print("Shape of augumented X_test:", augumented_X_test.shape)
# Out:
# Shape of augumented y_onehot_encoded: (1624, 3)
# Shape of augumented X_train: (1136, 256, 256, 3)
# Shape of augumented X_val: (325, 256, 256, 3)
# Shape of augumented X_test: (163, 256, 256, 3)

# %% [markdown]
# After using the data augmentation, the number of images in the data set have doubled from 812 to 1624. as well as the augmented train, validation and testing set have also doubled respectively.

# %%
V2_X_train = augumented_X_train
V2_X_test = augumented_X_test
V2_X_val = augumented_X_val

V2_y_train = augumented_y_train
V2_y_test = augumented_y_test
V2_y_val = augumented_y_val

# %% [markdown]
# ### Iteration 3

# %% [markdown]
# Since data augmentation has been ineffective in improving the model's performance, transfer learning will be used, as it's method that works well with small datasets. Transfer learning helps improve performance on new, related task with limited data by applying knowledge from a pre-trained model on a different task.
#
# In this iteration, feature-based transfer learning will be used, in which the model's lower layers extract features and only the upper layers need to be retrained for the new task. This is not the same as fine-tuning, which involves retraining the entire model.
# To evaluate its efficacy, transfer learning will be first applied to the original data. This entails redistributing the same data from the prior iteration to new variables in the transfer learning model's training, testing, and validation sets.

# %%
V3_X_train = og_X_train
V3_X_test = og_X_test
V3_X_val = og_X_val

V3_y_train = og_y_train
V3_y_test = og_y_test
V3_y_val = og_y_val

# %% [markdown]
# ## Task 3.3 CNN Architecture

# %% [markdown]
# ### Iteration 1

# %% [markdown]
# After sorting and preparing the data, the next step in the Machine Learning Project Lifecycle is to pick and train the model. it is aimed to create a simple model using a basic CNN setup for image classification. different setups have been performed, like changing layer types and settings, to find the best one. Eventually, a CNN model with 32 and 64 filters was chosen, using ReLU activation and max pooling to reduce image size. dropout has been added to prevent overfitting and ended with a dense layer for final classification. The model has over 2,117,059 parameters to be trained.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense

# Instantiate the model
V1_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3), padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])

#  Summarize the model
V1_model.summary()

      
def compile_model(model, lr):
      opt = Adam(learning_rate=lr)
      model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
      return 
      


# Compile the model
V1_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = V1_model.fit(V1_X_train, V1_y_train,
                                    epochs=30,
                                    batch_size=32,
                                    validation_data=(V1_X_val, V1_y_val))

# Evaluate the model
test_loss, test_acc = V1_model.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Model: "sequential_23"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_34 (Conv2D)          (None, 128, 128, 32)      896
#
#  max_pooling2d_34 (MaxPooli  (None, 64, 64, 32)        0
#  ng2D)
#
#  conv2d_35 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_35 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  flatten_16 (Flatten)        (None, 16384)             0
#
#  dropout_11 (Dropout)        (None, 16384)             0
#
#  dense_62 (Dense)            (None, 128)               2097280
#
#  dense_63 (Dense)            (None, 3)                 387
#
# ...
# Total params: 2117059 (8.08 MB)
# Trainable params: 2117059 (8.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# ...

# %% [markdown]
# Model 2:

# %%
model_2 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3), padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])

# Summarize the model
model_2.summary()

# Compile the model
model_2.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model_2.fit(V1_X_train, V1_y_train,
                                    epochs=30,
                                    batch_size=64,
                                    validation_data=(V1_X_val, V1_y_val))

# Evaluate the model
test_loss, test_acc = model_2.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Model: "sequential_24"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_36 (Conv2D)          (None, 128, 128, 32)      896
#
#  max_pooling2d_36 (MaxPooli  (None, 64, 64, 32)        0
#  ng2D)
#
#  conv2d_37 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_37 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  flatten_17 (Flatten)        (None, 16384)             0
#
#  dense_64 (Dense)            (None, 128)               2097280
#
#  dense_65 (Dense)            (None, 3)                 387
#
# ...
# Total params: 2117059 (8.08 MB)
# Trainable params: 2117059 (8.08 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 9/9 [==============================] - 3s 218ms/step - loss: 1.0976 - accuracy: 0.3439 - val_loss: 1.0880 - val_accuracy: 0.4233
# Epoch 2/30
# ...

# %%
model_3 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3), strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])

#  Summarize the model
model_3.summary()

# Compile the model
model_3.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model_3.fit(V1_X_train, V1_y_train,
                                    epochs=30,
                                    batch_size=32,
                                    validation_data=(V1_X_val, V1_y_val))

# Evaluate the model
test_loss, test_acc = model_3.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_38 (Conv2D)          (None, 127, 127, 32)      896
#
#  max_pooling2d_38 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_39 (Conv2D)          (None, 31, 31, 64)        18496
#  max_pooling2d_39 (MaxPooli  (None, 15, 15, 64)        0
#  ng2D)
#
#  flatten_18 (Flatten)        (None, 14400)             0
#
#  dropout_12 (Dropout)        (None, 14400)             0
#
#  dense_66 (Dense)            (None, 128)               1843328
#
#  dense_67 (Dense)            (None, 3)                 387
#
# ...
# Total params: 1863107 (7.11 MB)
# Trainable params: 1863107 (7.11 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/30
# 18/18 [==============================] - 4s 127ms/step - loss: 1.0997 - accuracy: 0.3668 - val_loss: 1.0904 - val_accuracy: 0.4233
# ...

# %%
model_4 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(256, (3, 3), activation='relu', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(3, activation='softmax')
])

# Summarize the model
model_4.summary()

# Compile the model
model_4.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model_4.fit(V1_X_train, V1_y_train,
                                    epochs=30,
                                    batch_size=32,
                                    validation_data=(V1_X_val, V1_y_val))

# Evaluate the model
test_loss, test_acc = model_4.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Model: "sequential_26"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_40 (Conv2D)          (None, 254, 254, 32)      896
#
#  max_pooling2d_40 (MaxPooli  (None, 127, 127, 32)      0
#  ng2D)
#
#  conv2d_41 (Conv2D)          (None, 63, 63, 64)        18496
#
#  max_pooling2d_41 (MaxPooli  (None, 31, 31, 64)        0
#  ng2D)
#
#  conv2d_42 (Conv2D)          (None, 15, 15, 128)       73856
#
#  max_pooling2d_42 (MaxPooli  (None, 7, 7, 128)         0
#  ng2D)
#
#  conv2d_43 (Conv2D)          (None, 3, 3, 256)         295168
#
#  max_pooling2d_43 (MaxPooli  (None, 1, 1, 256)         0
#  ng2D)
#
#  flatten_19 (Flatten)        (None, 256)               0
#
#  dense_68 (Dense)            (None, 128)               32896
#
#  dense_69 (Dense)            (None, 3)                 387
#
# ...
# Total params: 421699 (1.61 MB)
# Trainable params: 421699 (1.61 MB)
# Non-trainable params: 0 (0.00 Byte)
# ...

# %%
model_5 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3), strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(256, activation='relu'),
    Dropout(0.5),
    Dense(3, activation='softmax')
])

# Summarize the model
model_5.summary()

# Compile the model
model_5.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
history = model_5.fit(V1_X_train, V1_y_train,
                                    epochs=30,
                                    batch_size=32,
                                    validation_data=(V1_X_val, V1_y_val))

# Evaluate the model
test_loss, test_acc = model_5.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_acc)
# Out:
# Model: "sequential_27"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_44 (Conv2D)          (None, 127, 127, 32)      896
#
#  max_pooling2d_44 (MaxPooli  (None, 63, 63, 32)        0
#  ng2D)
#
#  conv2d_45 (Conv2D)          (None, 63, 63, 64)        18496
#
#  max_pooling2d_45 (MaxPooli  (None, 31, 31, 64)        0
#  ng2D)
#
#  conv2d_46 (Conv2D)          (None, 31, 31, 128)       73856
#
#  max_pooling2d_46 (MaxPooli  (None, 15, 15, 128)       0
#  ng2D)
#
#  flatten_20 (Flatten)        (None, 28800)             0
#
#  dense_70 (Dense)            (None, 256)               7373056
#
#  dropout_13 (Dropout)        (None, 256)               0
#
#  dense_71 (Dense)            (None, 3)                 771
#
# ...
# Total params: 7467075 (28.48 MB)
# Trainable params: 7467075 (28.48 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# ...

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# In the second iteration, the same model as the first iteration is used, however, it includes the augmented dataset during the training model process. the variables from the second iteration of the preprocessing will be used with the augmented dataset assigned to them.

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense

V2_model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(256, 256, 3), padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same', strides=(2, 2)),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dropout(0.5),
    Dense(64, activation='relu'),
    Dense(3, activation='softmax')
])

#  Summarize the model
V2_model.summary()
# Out:
# Model: "sequential_28"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_47 (Conv2D)          (None, 128, 128, 32)      896
#
#  max_pooling2d_47 (MaxPooli  (None, 64, 64, 32)        0
#  ng2D)
#
#  conv2d_48 (Conv2D)          (None, 32, 32, 64)        18496
#
#  max_pooling2d_48 (MaxPooli  (None, 16, 16, 64)        0
#  ng2D)
#
#  flatten_21 (Flatten)        (None, 16384)             0
#
#  dropout_14 (Dropout)        (None, 16384)             0
#
#  dense_72 (Dense)            (None, 64)                1048640
#
#  dense_73 (Dense)            (None, 3)                 195
#
# ...
# Total params: 1068227 (4.07 MB)
# Trainable params: 1068227 (4.07 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Iteration 3

# %% [markdown]
# In this iteration, a pre-trained model called VGG16 is used for the project. VGG16 is known for its ability to understand images well. it was chosen because it has many layers that can learn complex things from images. the model is not created from scratch but rather, built on top of what VGG16 already knows.
#
# this was by adding some extra layers on top of VGG16. These layers help the model understand their specific task better. it was made a point during the trial and error of the training process to made sure that VGG16's original learning stays the same and doesn't change.
#
# the model's structure was checked to see how many layers it has and how many things it can learn.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dropout, Dense
from tensorflow.keras.applications import VGG16
from tensorflow.keras import layers, models

# Load pre-trained VGG16 model
base_model = VGG16(weights='imagenet', include_top=False, input_shape=(256, 256, 3))

# Freeze the convolutional base
base_model.trainable = False

# Create a new model on top
V3_model = Sequential([
    base_model,
    Flatten(),
    Dropout(0.5),
    Dense(256, activation="relu"),
    Dense(3, activation="softmax")
])

# Summarize the model
V3_model.summary()
# Out:
# Model: "sequential_29"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 8, 8, 512)         14714688
#
#  flatten_22 (Flatten)        (None, 32768)             0
#
#  dropout_15 (Dropout)        (None, 32768)             0
#
#  dense_74 (Dense)            (None, 256)               8388864
#
#  dense_75 (Dense)            (None, 3)                 771
#
# ...
# Total params: 23104323 (88.14 MB)
# Trainable params: 8389635 (32.00 MB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %% [markdown]
# ## Task 3.4 CNN Training

# %% [markdown]
# ### Iteration 1

# %% [markdown]
# The process starts with defining a model and then training it with prepared data. it uses a special optimizer called Adam, which helps adjust the model's learning rate as it trains. To measure how well the model is doing, they calculate the categorical cross-entropy, which is good for problems where things can belong to multiple classes, like sorting images into different classes. They also keep an eye on accuracy to see how well the model is doing overall.
#
# To avoid the model getting good at the training old data but bad at new data (overfitting), EarlyStopping is used because it stops the training if the model's performance doesn't get better for a while on a separate set of validation data. They train the model for 30 epochs, adjusting its settings each time based on the results.
#
# During training, the data used for training called  (V1_X_train and V1_y_train) and for checking how well it's doing is called (V1_X_val and V1_y_val).
#
# After training, it is shown how the model improves over time and compare how it does on old training data versus new data using graphs/plots. This helps them see if the model is learning well or if there are problems like learning too much from the old training data and not enough from new data. matplotlib is used to make these graphs and then display them for analysis.

# %%
from tensorflow.keras.callbacks import EarlyStopping
import matplotlib.pyplot as plt

# Compile the model
V1_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Instantiate an early stopping callback
callback = EarlyStopping(monitor="val_loss", patience=2, restore_best_weights=True)

# Train the model
V1_history = V1_model.fit(V1_X_train, V1_y_train, epochs=30, batch_size=32, validation_data=(V1_X_val, V1_y_val), callbacks=[callback])

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy and validation accuracy
num_epochs_acc = len(V1_history.history["val_accuracy"])
epochs_axis_acc = np.arange(1, num_epochs_acc + 1)
axs[0].plot(epochs_axis_acc, V1_history.history["accuracy"], label="Train accuracy", marker = "o")
axs[0].plot(epochs_axis_acc, V1_history.history["val_accuracy"], label="Validation accuracy", marker = "o")
axs[0].set_xticks(epochs_axis_acc)
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot loss and validation loss
num_epochs_loss = len(V1_history.history["val_loss"])
epochs_axis_loss = np.arange(1, num_epochs_loss + 1)
axs[1].plot(epochs_axis_loss, V1_history.history["loss"], label="Train loss", marker = "o")
axs[1].plot(epochs_axis_loss, V1_history.history["val_loss"], label="Validation loss", marker = "o")
axs[1].set_xticks(epochs_axis_loss)
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Epoch 1/30
# 18/18 [==============================] - 3s 115ms/step - loss: 0.7485 - accuracy: 0.6808 - val_loss: 0.8757 - val_accuracy: 0.5706
# Epoch 2/30
# 18/18 [==============================] - 2s 92ms/step - loss: 0.7518 - accuracy: 0.6702 - val_loss: 0.8585 - val_accuracy: 0.6012
# Epoch 3/30
# 18/18 [==============================] - 2s 96ms/step - loss: 0.7498 - accuracy: 0.6702 - val_loss: 0.8655 - val_accuracy: 0.5828
# Epoch 4/30
# 18/18 [==============================] - 2s 93ms/step - loss: 0.7251 - accuracy: 0.6843 - val_loss: 0.8650 - val_accuracy: 0.5828

# %% [markdown]
# the process early stopped at the 4th epoch which indicates that the model stopped improving.
#
# The first plot visualizes the comparison between the train accuracy which peaked at 68% and validation accuracy which peaked in the 2nd epoch 60% but stopped at 58%.
#
# In the second plot, the train loss stopped at 0.72 and the validation loss stopped at 0.86

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# In this iteration, the same methods of compiling and training the model are used, the only difference is the useage of the variables from the second iteration in the preprocessing. the variables are both original and augmented data, which would make the dataset larger. this is done to see how the size of the dataset would effect the CNN model that was designed.
#
# the accuracy and loss curves will be visualized to gain insight on the progress of the model's learning process with the augmented and unseen data.

# %%
# Compile the model
V2_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Instantiate an early stopping callback
callback = EarlyStopping(monitor="val_loss", patience=2, restore_best_weights=True)

# Train the model
V2_history = V2_model.fit(V2_X_train, V2_y_train, epochs=30, batch_size=32, validation_data=(V2_X_val, V2_y_val), callbacks=[callback])

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy and validation accuracy
num_epochs_acc = len(V2_history.history["val_accuracy"])
epochs_axis_acc = np.arange(1, num_epochs_acc + 1)
axs[0].plot(epochs_axis_acc, V2_history.history["accuracy"], label="Train accuracy", marker = "o")
axs[0].plot(epochs_axis_acc, V2_history.history["val_accuracy"], label="Validation accuracy", marker = "o")
axs[0].set_xticks(epochs_axis_acc)
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot loss and validation loss
num_epochs_loss = len(V2_history.history["val_loss"])
epochs_axis_loss = np.arange(1, num_epochs_loss + 1)
axs[1].plot(epochs_axis_loss, V2_history.history["loss"], label="Train loss", marker = "o")
axs[1].plot(epochs_axis_loss, V2_history.history["val_loss"], label="Validation loss", marker = "o")
axs[1].set_xticks(epochs_axis_loss)
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Epoch 1/30
# 36/36 [==============================] - 5s 101ms/step - loss: 0.3274 - accuracy: 0.8741 - val_loss: 0.7883 - val_accuracy: 0.7138
# Epoch 2/30
# 36/36 [==============================] - 3s 86ms/step - loss: 0.2200 - accuracy: 0.9313 - val_loss: 0.7441 - val_accuracy: 0.7231
# Epoch 3/30
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1930 - accuracy: 0.9296 - val_loss: 0.9156 - val_accuracy: 0.6923
# Epoch 4/30
# 36/36 [==============================] - 3s 85ms/step - loss: 0.1830 - accuracy: 0.9410 - val_loss: 0.8943 - val_accuracy: 0.7415

# %% [markdown]
# the process early stopped at the 4th epoch which indicates that the model stopped improving.
#
# The first plot visualizes the comparison between the train accuracy which peaked at 94% and validation accuracy which peaked at 74%.
#
# In the second plot, the train loss stopped at 0.18 and the validation loss stopped at 0.74

# %% [markdown]
# ### Iteration 3

# %% [markdown]
# In this iteration, the same methods of compiling and training the model are used, the only difference is the useage of the variables from the third iteration in the preprocessing. The variables only contain the origival dataset without any data augmentation included.
#
# this iteration employs transfer learning methods in the CNN model, thus the original preprocessed dataset is used to evaluate its accuracy compared to the basic CNN model. also, the loss curve and accuracy are visualized to gain insights on the model's progress similarly to the previous iterations.

# %%
# Compile the model
V3_model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# Instantiate an early stopping callback
callback = EarlyStopping(monitor="val_loss", patience=2, restore_best_weights=True)

# Train the model
V3_history = V3_model.fit(V3_X_train, V3_y_train, epochs=30, batch_size=32, validation_data=(V3_X_val, V3_y_val), callbacks=[callback])

# Create subplots
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

# Plot accuracy and validation accuracy
num_epochs_acc = len(V3_history.history["val_accuracy"])
epochs_axis_acc = np.arange(1, num_epochs_acc + 1)
axs[0].plot(epochs_axis_acc, V3_history.history["accuracy"], label="Train accuracy", marker = "o")
axs[0].plot(epochs_axis_acc, V3_history.history["val_accuracy"], label="Validation accuracy", marker = "o")
axs[0].set_xticks(epochs_axis_acc)
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Accuracy")
axs[0].legend()

# Plot loss and validation loss
num_epochs_loss = len(V3_history.history["val_loss"])
epochs_axis_loss = np.arange(1, num_epochs_loss + 1)
axs[1].plot(epochs_axis_loss, V3_history.history["loss"], label="Train loss", marker = "o")
axs[1].plot(epochs_axis_loss, V3_history.history["val_loss"], label="Validation loss", marker = "o")
axs[1].set_xticks(epochs_axis_loss)
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Loss")
axs[1].legend()

# Adjust layout
plt.tight_layout()

# Show plot
plt.show()
# Out:
# Epoch 1/30
# 18/18 [==============================] - 90s 5s/step - loss: 1.4380 - accuracy: 0.3228 - val_loss: 1.1941 - val_accuracy: 0.2638
# Epoch 2/30
# 18/18 [==============================] - 95s 5s/step - loss: 1.1541 - accuracy: 0.3457 - val_loss: 1.0849 - val_accuracy: 0.4233
# Epoch 3/30
# 18/18 [==============================] - 90s 5s/step - loss: 1.1161 - accuracy: 0.3492 - val_loss: 1.1097 - val_accuracy: 0.3129
# Epoch 4/30
# 18/18 [==============================] - 93s 5s/step - loss: 1.1272 - accuracy: 0.3457 - val_loss: 1.1390 - val_accuracy: 0.2638

# %% [markdown]
# the process early stopped at the 4th epoch which indicates that the model stopped improving.
#
# The first plot visualizes the comparison between the train accuracy which peaked in the 3rd epoch at 43.9% and validation accuracy which peaked in the 2nd epoch at 42%.
#
# In the second plot, the train loss stopped at 1.12 and the validation loss stopped at 1.13

# %% [markdown]
# ## Task 3.5 Model Performance

# %% [markdown]
# ### Iteration 1

# %% [markdown]
# After the models have been trained, in this section, the perfomance is evaluated using the test datasets to calculate the test loss and accuracy using the evaluate method.
#
# The model's performance is also assessed by using a confusion matrices and a classification report. the probabilities are first predicted into the class labels usinf the predict method. then these probabilities are converted into class labels.
#
# A confusion matrix is calculated by employing th e confusion_matrix function imported form scikit.metrics. after all that is done, a classification report is generated using the classification_report function, which refines the details of the metrics such as recall, F1 score and precision for each class.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import classification_report

# Evaluate the model
V1_test_loss, V1_test_acc = V1_model.evaluate(V1_X_test, V1_y_test)
print("Test Loss:", V1_test_loss)
print("Test Accuracy:", V1_test_acc)

# Predict probabilities for the test set
V1_y_pred_prob = V1_model.predict(V1_X_test)

# Convert probabilities to class labels
V1_y_pred = np.argmax(V1_y_pred_prob, axis=1)

# Calculate confusion matrix
V1_cm = confusion_matrix(V1_y_test.argmax(axis=1), V1_y_pred)

# Calculate classification report
V1_report = classification_report(np.argmax(V1_y_test, axis=1), V1_y_pred)

# Display metrics
print("\n Confusion matrix: \n", V1_cm)
print("\n Classification report: \n", V1_report)
# Out:
# 3/3 [==============================] - 0s 25ms/step - loss: 0.8810 - accuracy: 0.6098
# Test Loss: 0.8810101747512817
# Test Accuracy: 0.6097561120986938
# 3/3 [==============================] - 0s 21ms/step
#
#  Confusion matrix:
#  [[12  5  5]
#  [ 6 17  5]
#  [ 5  6 21]]
#
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.55      0.53        22
#            1       0.61      0.61      0.61        28
#            2       0.68      0.66      0.67        32
#
#     accuracy                           0.61        82
#    macro avg       0.60      0.60      0.60        82
# weighted avg       0.61      0.61      0.61        82

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# This iteration will use all the same functions and evaluation methods explained in the first iteration. those being, test loss, accruacy, confusion matrices and classification report as well as precision, recall, F1 scrore for each class.

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

# Evaluate the model
V2_test_loss, V2_test_acc = V2_model.evaluate(V2_X_test, V2_y_test)
print("Test Loss:", V2_test_loss)
print("Test Accuracy:", V2_test_acc)

# Predict probabilities for the test set
V2_y_pred_prob = V2_model.predict(V2_X_test)

# Convert probabilities to class labels
V2_y_pred = np.argmax(V2_y_pred_prob, axis=1)

# Calculate confusion matrix
V2_cm = confusion_matrix(V2_y_test.argmax(axis=1), V2_y_pred)

# Calculate classification report
V2_report = classification_report(np.argmax(V2_y_test, axis=1), V2_y_pred)

# Display metrics
print("\n Confusion matrix: \n", V2_cm)
print("\n Classification report: \n", V2_report)
# Out:
# 6/6 [==============================] - 0s 20ms/step - loss: 0.7142 - accuracy: 0.7055
# Test Loss: 0.7142062187194824
# Test Accuracy: 0.7055214643478394
# 6/6 [==============================] - 0s 20ms/step
#
#  Confusion matrix:
#  [[32  6  5]
#  [12 31  6]
#  [ 8 11 52]]
#
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.62      0.74      0.67        43
#            1       0.65      0.63      0.64        49
#            2       0.83      0.73      0.78        71
#
#     accuracy                           0.71       163
#    macro avg       0.70      0.70      0.70       163
# weighted avg       0.72      0.71      0.71       163

# %% [markdown]
# ### Iteration 3

# %% [markdown]
# This iteration will use all the same functions and evaluation methods explained in the first iteration. those being, test loss, accruacy, confusion matrices and classification report as well as precision, recall, F1 scrore for each class.

# %%
import matplotlib.pyplot as plt

# Evaluate the model
V3_test_loss, V3_test_acc = V3_model.evaluate(V3_X_test, V3_y_test)
print("Test Loss:", V3_test_loss)
print("Test Accuracy:", V3_test_acc)

# Predict probabilities for the test set
V3_y_pred_prob = V3_model.predict(V3_X_test)

# Convert probabilities to class labels
V3_y_pred = np.argmax(V3_y_pred_prob, axis=1)

# Calculate confusion matrix
V3_cm = confusion_matrix(V3_y_test.argmax(axis=1), V3_y_pred)

# Calculate classification report
V3_report = classification_report(np.argmax(V3_y_test, axis=1), V3_y_pred)

# Display metrics
print("\n Confusion matrix: \n", V3_cm)
print("\n Classification report: \n", V3_report)
# Out:
# 3/3 [==============================] - 13s 4s/step - loss: 1.1032 - accuracy: 0.3902
# Test Loss: 1.1032390594482422
# Test Accuracy: 0.39024388790130615
# 3/3 [==============================] - 13s 4s/step
#
#  Confusion matrix:
#  [[ 0  0 22]
#  [ 0  0 28]
#  [ 0  0 32]]
#
#  Classification report:
#                precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        22
#            1       0.00      0.00      0.00        28
#            2       0.39      1.00      0.56        32
#
#     accuracy                           0.39        82
#    macro avg       0.13      0.33      0.19        82
# weighted avg       0.15      0.39      0.22        82
# c:\Users\sally\anaconda3\envs\block_c\lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# _________

# %% [markdown]
# ## Task 3.6 Error Analysis

# %% [markdown]
# - iteration 1: basic dataset. test loss: 0.88 accuracy: 60%
# - iteration 2: data augmentation. test loss: 0.71 accuracy: 70%
# - iteration 3: transfer learning. test loss: 1.1 accuracy: 39%

# %% [markdown]
# After the model performance evaluation has been performed, and results show that the 2nd iteration is the best performing out of the 3 iterations, followed by the 1st iteration and lastly the 3rd iteration.
#
# Thus the 2nd iteration has been chosen for the error analysis, as it has the accuracy of 70% and test loss of 0.71, which shows the effectiveness of data augmentation in the hair texture dataset.

# %% [markdown]
# ### Iteration 2

# %% [markdown]
# Performing the error analysis will aid in potentially improving the model by finding patterns within the wrong predictions and understanding why such error happen.
#
# First, the labels are predicted for the test set using the trained model and are compared to the true labels. then, the misclassified images, predicted labels and true labels are displayed to provide a visual understanding. then, the images are manually analyzed and then the misclassified images are catagorized in labels with common characteristics and patterns. based on the analysis, a hypothses is developed about why the errors are occuring.

# %%
# Predict labels for the test set
V2_y_pred = np.argmax(V2_model.predict(V2_X_test), axis=1)

# Find misclassified indices
misclassified_indices = np.where(V2_y_pred != np.argmax(V2_y_test, axis=1))[0]

# Display all misclassified images along with their true labels and predicted labels
num_misclassified = len(misclassified_indices)
num_cols = 6
num_rows = (num_misclassified + num_cols - 1) // num_cols  # Ceiling division

plt.figure(figsize=(15, 5*num_rows))
for i, index in enumerate(misclassified_indices):
    plt.subplot(num_rows, num_cols, i + 1)
    plt.imshow(V2_X_test[index])
    plt.title(f"{i+1}.\nTrue label: {class_names[np.argmax(V2_y_test[index])]} \nPredicted label: {class_names[V2_y_pred[index]]}")
    plt.axis('off')
plt.show()

# Print the total number of misclassified images
print("\n Number of misclassified images:", len(misclassified_indices))
# Out:
# 6/6 [==============================] - 0s 15ms/step
#  Number of misclassified images: 48

# %% [markdown]
# After analyzing the images, a few common themes seem to show up, those being:
#
# - Short hair being mistaken for straight.
# - images with darker skinned people are more likely to be catagorized with curly or wavy hair.
# - people with blond hair are more likely to be catagorized with straight hair.
#
# In conclusion, it seems that the model may have a racial bias that was unaccounted for, as well as a gender bias which was discussed in the earlier sections, as people with short hair are more likely to be mistaken for having striaght hair, despite the clear curl pattern which might indicate that men/ non-binary people and women with short hair might not get accurate results.

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Calculate confusion matrix
V2_conf_matrix = confusion_matrix(np.argmax(V2_y_test, axis=1), V2_y_pred)

# Plot confusion matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(V2_conf_matrix, annot=True, cmap="Purples", fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# Calculate per-class accuracy
per_class_accuracy = V2_conf_matrix.diagonal() / V2_conf_matrix.sum(axis=1)

# Print per-class accuracy
print("\nAccuracy per each class:")
for i, class_name in enumerate(class_names):
    print(f"{class_name}: {per_class_accuracy[i]}")
# Out:
# Accuracy per each class:
# Straight: 0.7441860465116279
# Wavy: 0.6326530612244898
# Curly: 0.7323943661971831

# %% [markdown]
# In the matrix above, the occurances of misclassified images can be seen. the diagonal shows the correct predictions. while the rest are the misclassifications.
#
# - Number of correct predictions: 115
# - Number of incorrect predictions: 48
#
# The accuracy per class:
# - Straight: decent accuracy at 74%, which means that 26% of the images were misclassified.
# - Wavy: decent accuracy at 63%, which means that 37% of the images were misclassified.
# - Curly: decent accuracy at 73%, which means that 27% of the images were misclassified.
#
# The accuracy per class differ, with both straight and curly are very close at 74% and 73% respectively, while Wavy is 10% lower at 63%.

# %% [markdown]
# ## Task 3.7 MLP From Scratch

# %% [markdown]
# Add your text here!

# %%
from skimage import io as ski_io
import os
import numpy as np
import skimage as ski
import random

# Folder paths where the images of each class are stored
folder_paths = [
    r".//Raw Dataset/Curly",
    r".//Raw Dataset/Wavy",
    r".//Raw Dataset/Straight"
]

# Class labels for the images (same order as folder_paths)
class_names = [
    "straight",
    "wavy",
    "curly"
]

# Target size to resize the images
target_size = (16, 16)

# Arrays to store the images (X) and class labels (y)
X = []
y = []

# Specify the number of images to be loaded
num_images_per_folder = 20

for i in range(len(folder_paths)):
    # List all files in the folder
    files = os.listdir(folder_paths[i])
    # Select 20 files randomly
    files_to_load = random.sample(files, min(num_images_per_folder, len(files)))
    for filename in files_to_load:
        file_extension = os.path.splitext(filename)[1]
        # Check if the file extension is an image extension
        if file_extension.lower() in ['.jpg', '.jpeg', '.png']:
            image_filename = os.path.join(folder_paths[i], filename)
            # Read the image file using scikit-image
            image = ski_io.imread(image_filename, as_gray = True)
            # Resize the image to the target_size
            image_resized = ski.transform.resize(image, target_size)
            if image_resized.shape == (16, 16):
                # Normalize the image
                # image_normalized = image_resized / 255.0
                # Insert the image into array X
                X.append(image_resized)
                # Insert the class label into array y
                y.append(class_names[i])
            else:
                print(filename)

# Convert of arrays into numpy arrays
X = np.array(X)
y = np.array(y)

# %%
from sklearn import preprocessing
import keras

# Initialize LabelEncoder with class names
label_encoder = preprocessing.LabelEncoder()
label_encoder.classes_ = np.array(class_names)

# Encode class labels
y_integer_encoded = label_encoder.transform(y)

# Convert integer-encoded labels into one-hot encoded vectors
y_onehot_encoded = keras.utils.to_categorical(y_integer_encoded, num_classes=len(class_names))

# Split the data into train and test sets
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y_onehot_encoded, test_size = 1/10, random_state = 0)

# Split the data into train, test and validations sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size = 2/9, random_state = 0)

# Reshape the input data
X_train_reshaped = X_train.reshape(-1, 16*16)
X_test_reshaped = X_test.reshape(-1, 16*16)
X_val_reshaped = X_val.reshape(-1, 16*16)

# %%
from copy import deepcopy

def initializer(nn_architecture):
    '''
    Given
    - the number of layers
    - the number of units in each layer
    initializes network parameters (weights and biases)

    Arguments
        nn_architecture: a list of integers
                         length of the list is the number of layers
                         each item in the list specifies
                         the number of units in that layer
    Returns
        weights: list of numpy arrays, w0, w1, ...
        biases: list of numpy arrays, b0, b1, ...

    '''
    weights = []
    biases = []

    # SOLUTION CODE BEGIN #
    for l in range(0, len(nn_architecture)-1):
        w = np.random.randn(nn_architecture[l], nn_architecture[l+1])
        weights.append(w)
        b = np.random.randn(1, nn_architecture[l+1])
        biases.append(b)
    # SOLUTION CODE END #

    return weights, biases

def sigmoid(x):
    '''
    Calculates the sigmoid of an input
    Arguments
        x: np.array() of real numbers
    Returns
        np.array() of real numbers between 0 and 1

    '''
    # Applying sigmoid function element-wise to the input array
    return 1 / (1 + np.exp(-x))

def predict(X, weights, biases):
    '''
    Given an input and NN parameters,
    this function calculates the output

    Arguments
        X: np.array() of shape
        (#datapoints, #features)
        weights: list of np arrays
        biases: list of np arrays
    Returns
        y_pred: np.array() of shape
        (#datapoints, #classes)

    '''

    # SOLUTION CODE BEGIN #
    layer_input = X
    for i in range(len(weights)):
        layer_output = sigmoid(np.dot(layer_input, weights[i]) + biases[i])
        layer_input = layer_output
    y_pred = layer_output
    # SOLUTION CODE END #

    return y_pred

# Task 4
def accuracy(y_pred_binary, y):
    '''
    Given
    -binary predictions
    -labels
    calculates accuracy

    '''

    # SOLUTION CODE BEGIN #
    return sum(y_pred_binary == y)/len(y)
    # SOLUTION CODE END #


def loss_function(X, y, weights, biases):
    losses = []
    for i in range(len(X)):
        prediction = predict(X[i], weights, biases)
        # Cross-entropy loss calculation
        loss = -np.sum(y[i] * np.log(prediction))
        losses.append(loss)

    return np.mean(losses)



# Task 6.1
def weight_update(weights, layer_id, i, j, new_param):
    '''
    Given a single weight defined by (layer_id, i, j)
    updates it with a new parameter (new_param)

    Arguments
        weights: list of np.arrays()
        layer_id: integer
        i: integer
        j: integer
        new_param: float
    Return
        new_w: list of np.arrays()
               where only a single value is changed
               compared to weights

    '''
    # It is important to create a copy of the weights and update the copy
    new_w = deepcopy(weights)

    # SOLUTION CODE BEGIN #
    layer_w = weights[layer_id]
    new_layer_w = layer_w.copy()
    new_layer_w[i, j] = new_param
    new_w[layer_id] = new_layer_w
    # SOLUTION CODE END #

    return new_w

# Task 6.2
def bias_update(biases, layer_id, j, new_param):
    '''
    Given a single bias defined by (layer_id, j)
    updates it with a new parameter (new_param)

    Arguments
        biases: list of np.arrays()
        layer_id: integer
        j: integer
        new_param: float
    Return
        new_b: list of np.arrays()
               where only a single value is changed

    '''

    # It is important to create a copy and update the copy
    new_b = deepcopy(biases)

    # SOLUTION CODE BEGIN #
    layer_b = biases[layer_id]
    new_layer_b = layer_b.copy()
    new_layer_b[0, j] = new_param
    new_b[layer_id] = new_layer_b
    # SOLUTION CODE END #

    return new_b

# Task 6.3
def gradient_estimator(X, y, weights, biases):
    '''
    This function estimates

    ∂(loss_function)/∂(w_ij) and
    ∂(loss_function)/∂(b_ij)

    for every weight and bias.

    ∂(loss_function)/∂(w_ij) can be estimated by
    [(loss for w_ij+epsilon) - (loss with w_ij)]/epsilon

    likewise

    ∂(loss_function)/∂(b_ij) can be estimated by
    [(loss for b_ij+epsilon) - (loss with b_ij)]/epsilon

    For each parameter in weights and biases,
    the function will estimate
    ∂(loss_function)/∂(w_ij) and ∂(loss_function)/∂(b_ij)
    and return a list of np.arrays()
    called w_pds and b_pds, respectively.

    Arguments
        X: input data
        y: labels
        weights: list of np arrays, weights of the MLP
        biases: list of np arrays, biases of the MLP
    Returns
        w_pds: list of np arrays, same dimensions with weights
        b_pds: list of np arrays, same dimensions with biases
    '''
    eps = 1e-4
    loss_val = loss_function(X, y, weights, biases)

    # partial derivatives for weights
    w_pds = []
    for layer_id, layer_w in enumerate(weights):
        pd_array = np.zeros(layer_w.shape)

        # Calculate the partial derivative (pd) for each weight
        # and save those values into pd_array

        # SOLUTION CODE BEGIN #
        for i in range(layer_w.shape[0]):
            for j in range(layer_w.shape[1]):

                wij = layer_w[i, j]

                wij_plus = wij + eps
                w_plus = weight_update(weights, layer_id, i, j, wij_plus)
                loss_plus = loss_function(X, y, w_plus, biases)

                pd = (loss_plus - loss_val)/eps
                pd_array[i, j] = pd
        # SOLUTION CODE END #

        w_pds.append(pd_array)

    # partial derivatives for biases
    b_pds = []
    for layer_id, layer_b in enumerate(biases):
        pd_array = np.zeros(layer_b.shape)

        # Calculate the partial derivative (pd) for each bias
        # and save those values into pd_array

        # SOLUTION CODE BEGIN #
        for j in range(layer_b.shape[1]):
            i = 0
            bij = layer_b[i, j]

            bij_plus = bij + eps
            b_plus = bias_update(biases, layer_id, j, bij_plus)
            loss_plus = loss_function(X, y, weights, b_plus)

            pd = (loss_plus - loss_val)/eps
            pd_array[i, j] = pd
        # SOLUTION CODE END #

        b_pds.append(pd_array)

    return w_pds, b_pds

def one_step_gradient_descent(X, y, weights, biases, lr):
    '''
    This function executes one step of gradient decent and updates weights and biases.

    First estimate the gradient using the gradient_estimator function implemented
    in the previous task.

    Then, update the params by:
    w = w - lr * w_pds
    b = b - lr * b_pds

    Arguments:
        X: input data
        y: labels
        weights: NN weights
        biases: NN biases
        lr: learning rate, a float
    Returns:
        new_w: updated weights, same size as weights
        new_b: updated biases, same size as biases

    '''
    w_pds, b_pds = gradient_estimator(X, y, weights, biases)

    new_w = []
    # For each weight array in weights list
    # use gradient descent update rule
    # append the array to new_w list

    # SOLUTION CODE BEGIN #
    for layer_id, layer_w in enumerate(weights):
        layer_new_w = layer_w - lr*w_pds[layer_id]
        new_w.append(layer_new_w)
    # SOLUTION CODE END #

    new_b = []
    # For each bias array in biases list
    # use gradient descent update rule
    # append the array to new_b list

    # SOLUTION CODE BEGIN #
    for layer_id, layer_b in enumerate(biases):
        layer_new_b = layer_b - lr*b_pds[layer_id]
        new_b.append(layer_new_b)
    # SOLUTION CODE END #

    return new_w, new_b

def gradient_descent(X, y, weights, biases, epoch, lr):
    '''
    Repeats one_step_gd()
    for given number of epochs
    Saves and plots the error at each epoch
    Arguments
        X: input data
        y: labels
        weights: NN weights
        biases: NN biases
        epoch: integer
        lr: float
    Return
        weights: learned weights
        biases: learned biases
    '''

    errors = []

    for i in range(epoch):

        # SOLUTION CODE BEGIN #
        weights, biases = one_step_gradient_descent(X, y, weights, biases, lr)
        error = loss_function(X, y, weights, biases)
        # SOLUTION CODE END #

        errors.append(error)

    plt.figure(dpi=200)
    plt.plot(errors)
    plt.xlabel('# epochs')
    plt.ylabel('loss')

    return weights, biases

import matplotlib.pyplot as plt

# %%
# Define MLP architecture
nn_architecture = [X_train_reshaped.shape[1], 64, 3]

# Initialize weights and biases
weights, biases = initializer(nn_architecture)

# Train the MLP using gradient descent
trained_weights, trained_biases = gradient_descent(X_train_reshaped, y_train, weights, biases, epoch=10, lr=0.1)

# %%
# Evaluate the MLP on the test set
y_pred_test = predict(X_test_reshaped, trained_weights, trained_biases)
test_preds = (y_pred_test > 0.5)*1
test_accuracy = accuracy(test_preds, y_test)

print("Test Accuracy:", test_accuracy)
# Out:
# Test Accuracy: [0.5        0.66666667 0.16666667]

# %% [markdown]
# # Section 4 - Human-Centered AI (Weeks 7 and 8)

# %% [markdown]
# ## Task 4.1: Think-Aloud Study

# %% [markdown]
# Link to the recording: https://edubuas-my.sharepoint.com/:v:/g/personal/211066_buas_nl/EVJ-v_GexQVFiPDREBVGxjUBD_5iNLlQABvZRKImgD2w9w?referrer=Teams.TEAMS-WEB&referrerScenario=MeetingChicletGetLink.view.view
#
# Figma Link: https://www.figma.com/file/lLxpXrX50CUSo9D9AMwkUa/Hair-image-classifier-prototype-V1.0?type=design&node-id=0%3A1&mode=design&t=8XEluoO3Dolv62eO-1
#
# The think-aloud study is a method in human centered AI that involves participants to verblize their thoughts and reactions as they interact with the application given to them.
#
# Before the study is conducted, a wireframe of the application was created on figma that is interactive for the participants to test and experience.
#
# Throughout the testing, most of the feedback that was given was about adding more interactive features rather than fixing any particular issues, which was generally taken as a good sign that the design was on the right track.

# %% [markdown]
# ## Task 4.2: A/B Testing

# %% [markdown]
# The instructions given:
#
# - Sign in
# - Navigate to Classifier where you can take a picture
# - Take a picture
# - See the result
# - Retake (optional)
# - See recommended products for the Hair type
# - Add item to the cart
# - check out
#
# ________________
#
# - Forms (Version_A): https://forms.office.com/e/cMjXE5N2s7
# - Forms (Version_B): https://forms.office.com/e/tEL3qcsKgx
# - Note: figma links for both versions are in the forms.
#
# Conclusion: Overall, it seems that version A performed slightly better than version B.

# %% [markdown]
# ## Task 4.3:  Create a Final Wireframe and Demo Video

# %% [markdown]
# - Demo Video: https://github.com/BredaUniversityADSAI/2023-24c-fai1-adsai-SallyIbrahim211066/blob/33dc9fed6127e985dd624d5c8141f8bd6b893ac0/Hair-texture-classifier-Demo.mp4
#
# - Figma Link: https://www.figma.com/file/lLxpXrX50CUSo9D9AMwkUa/Hair-image-classifier-prototype-V1.0?type=design&node-id=0%3A1&mode=design&t=8XEluoO3Dolv62eO-1

# %% [markdown]
# # Section 5 - Final Project Presentation (Week 8)

# %% [markdown]
# ## Task 5: Presentation Slides

# %% [markdown]
# Link: https://github.com/BredaUniversityADSAI/2023-24c-fai1-adsai-SallyIbrahim211066/blob/df1070261432e6411b26b8b780c306763e867070/Project%20Proposal.pptx
